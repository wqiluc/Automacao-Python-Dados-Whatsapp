# %% [markdown]
# # 🤖 Automação de Relatórios para WhatsApp
# ### Estrutura passo a passo da automação com Python<img src="https://raw.githubusercontent.com/devicons/devicon/master/icons/python/python-original.svg" alt="Python Logo" width="20">
#
# Bibliotecas: os; pyautogui; pyperclip; pandas; openpyxl, from time import sleep, cores.

# %% [markdown]
# ## 📚 Passo 1: Importar as bibliotecas
# Importar tudo necessário para automação; leitura de dados; controle do sistema; e envio das mensagens.

# %%
from cores import *
import os as system
import pandas as pd
import pyautogui as auto
import pyperclip as clip
from time import sleep
import openpyxl as excel

# %% [markdown]
# ## 🌐 Passo 2: Carregar base de dados da internet<img src="https://raw.githubusercontent.com/devicons/devicon/master/icons/pandas/pandas-original.svg" width="19"/>
# Uma das fontes de bases de dados que uso👇:<br>
# https://github.com/datablist/sample-csv-files
#
# Objetivo:
# ler os dados usando pandas e salvar em DataFrame.

# %%
# 👇 carregamento da base de dados
url_dados = (r"customers-1000.csv")
tabela_dados_original = pd.read_csv(url_dados)
display(tabela_dados_original)

# %% [markdown]
# ## 🧹<img src="https://raw.githubusercontent.com/devicons/devicon/master/icons/pandas/pandas-original.svg" width="19"/> Passo 3: Limpeza e extração das informações
# Selecionar colunas; remover valores nulos; preparar contatos para envio das mensagens.

# %%
# 👇 tratamento dos dados
tabela_dados_updated = tabela_dados_original.drop(columns=["Index", "Customer Id", "Phone 2"])
display(tabela_dados_updated)
tabela_dados_updated.drop_duplicates() # removendo itens e informações duplicadas
display(tabela_dados_updated)

#após a análise dessa base de dados, para melhor entendimento, retiramos o ID do cliente, o segundo número de telefone e o índice, que não são relevantes para a análise e podem causar confusão. A base de dados atualizada agora contém apenas as informações essenciais para a análise, como nome, sobrenome, empresa, cidade, país, telefone, data de assinatura e site. Essa limpeza dos dados facilita a visualização e interpretação das informações, permitindo uma análise mais clara e objetiva dos clientes cadastrados. Com isso, podemos focar nas variáveis mais importantes para entender o perfil dos clientes e suas características, sem a distração de informações irrelevantes. A base de dados atualizada está pronta para ser utilizada na criação de mensagens personalizadas e análises mais aprofundadas.

# %% [markdown]
# ## ✍️ Passo 4: Tradução da tabela e criação do template da mensagem🇧🇷🖊️
# Mensagem personalizada com emojis; utilizando o grupo onde ela será encaminhada.

# %%
# 👇 criação da mensagem automática e traduzindo a base de dados🇧🇷
print(f"{Negrito}{Amarelo}Abaixo está a base de dados dos nossos clientes atualizada para o{Reset} {Verde}português brasileiro 🇧🇷{Reset}\n ")

tabela_dados_updated2 = tabela_dados_updated.rename(columns={"First Name": "Nome", "Last Name": "Sobrenome", "Company": "Empresa", "City": "Cidade", "Country": "País", "Phone 1": "Telefone", "Subscription Date": "Data de Assinatura", "Website": "Site"})
display(tabela_dados_updated2)

for indice_cliente, (cliente) in (tabela_dados_updated2.iterrows()):
    nome = cliente["Nome"]
    sobrenome = cliente["Sobrenome"]
    empresa = cliente["Empresa"]
    cidade = cliente["Cidade"]
    país = cliente["País"]
    telefone = cliente["Telefone"]
    data_assinatura = cliente["Data de Assinatura"]
    site = cliente["Site"]
    total_clientes = tabela_dados_updated2["Nome"].count()


mensagem = (f"""📊 Relatório Analítico da Base de Clientes – Empresa Fictícia

Prezado time,

Realizamos uma análise completa da base de clientes considerando as informações disponíveis, incluindo nome, sobrenome, empresa, cidade, país, telefone, email, data de assinatura e site 🌐.

📈 Crescimento da Base:
Após 01/01/2021 foram registrados {data_assinatura} novos clientes, demonstrando evolução consistente no volume de assinaturas e fortalecimento da presença da empresa no período recente 🚀.

🌍 Distribuição Geográfica:
O país com maior concentração de clientes atualmente é {país}, indicando maior aderência dos serviços nessa região e potencial para ações estratégicas locais 📍.

🏢 Empresas e Presença Corporativa:
A base apresenta diversidade de empresas cadastradas, ampliando oportunidades comerciais e fortalecendo o relacionamento B2B 🤝.

📧 Contatos e Comunicação:
Todos os clientes possuem registros de telefone e email válidos, facilitando campanhas de marketing, comunicação direta e ações de suporte ao cliente 📞✉️.

🌐 Presença Digital:
O site mais recorrente identificado foi {site}, sugerindo maior recorrência de clientes vinculados a esse domínio e possível relevância estratégica no ambiente online 💻.

📅 Assinaturas:
As datas de assinatura indicam fluxo contínuo de entrada de clientes ao longo dos anos analisados, evidenciando estabilidade no processo de aquisição 📊.

👥 Base Atual:
O total atualizado de clientes cadastrados é {total_clientes}, considerando todos os registros válidos disponíveis na base.

Permanecemos à disposição para aprofundar análises adicionais, criar dashboards ou apoiar decisões estratégicas com base nesses dados.

Atenciosamente,
Lucas Paguetti Pereira🇮🇹
""")

# %% [markdown]
# ## 🌐📞 Passo 5: Abrir WhatsApp Web
# Abrir navegador automaticamente; acessar WhatsApp Web; aguardar carregamento.

# %%
# 👇 abrir WhatsApp
navegador = ("Safari".capitalize())
link_whatsapp_web = ("https://web.whatsapp.com/".lower())
destinatario = ("anotações".lower())
system.system(f"open -a" + f"{navegador}")
sleep(5)
auto.hotkey("command", "t")
auto.write(f"{link_whatsapp_web}")
sleep(5)
auto.press("enter")
sleep(5)
auto.click(x=1001, y=196)
sleep(2)
clip.copy(f"{destinatario}")
auto.hotkey("command", "v")
sleep(2)
auto.press("tab")
auto.press("tab")
auto.press("enter")
sleep(2)

# %% [markdown]
# ## 🖱️ Passo 6: Localizar contato
# Automação de mouse e teclado para pesquisar contato e abrir conversa.

# %%
# 👇 automação de navegação
#grupo "anotações"

# %% [markdown]
# ## 📤 Passo 7: Enviar mensagem
# Copiar mensagem; colar na conversa; enviar automaticamente.

# %%
# 👇 envio da mensagem
clip.copy(mensagem)
auto.hotkey("command", "v")
sleep(1)
auto.press("enter")
sleep(1)

mensagem_terminal = (f"""{Negrito}📊 Relatório Analítico da Base de Clientes – Empresa Fictícia{Reset}

{Negrito}Prezado time,{Reset}

{Negrito}Realizamos uma análise completa da base de clientes considerando as informações disponíveis, incluindo nome, sobrenome, empresa, cidade, país, telefone, email, data de assinatura e site 🌐.{Reset}

{Negrito}📈 Crescimento da Base:{Reset}
{Verde}Após 01/01/2021 foram registrados {Amarelo}{data_assinatura}{Verde} novos clientes, demonstrando evolução consistente no volume de assinaturas e fortalecimento da presença da empresa no período recente 🚀.{Reset}

{Negrito}🌍 Distribuição Geográfica:{Reset}
{Negrito}O país com maior concentração de clientes atualmente é {Amarelo}{país}{Reset}{Negrito}, indicando maior aderência dos serviços nessa região e potencial para ações estratégicas locais 📍.{Reset}

{Negrito}🏢 Empresas e Presença Corporativa:{Reset}
{Azul}A base apresenta diversidade de empresas cadastradas, ampliando oportunidades comerciais e fortalecendo o relacionamento B2B 🤝.{Reset}

{Negrito}📧 Contatos e Comunicação:{Reset}
{Magenta}Todos os clientes possuem registros de telefone e email válidos, facilitando campanhas de marketing, comunicação direta e ações de suporte ao cliente 📞✉️.{Reset}

{Negrito}🌐 Presença Digital:{Reset}
{Negrito}O site mais recorrente identificado foi {Amarelo}{site}{Reset}{Negrito}, sugerindo maior recorrência de clientes vinculados a esse domínio e possível relevância estratégica no ambiente online 💻.{Reset}

{Negrito}📅 Assinaturas:{Reset}
{Branco}As datas de assinatura indicam fluxo contínuo de entrada de clientes ao longo dos anos analisados, evidenciando estabilidade no processo de aquisição 📊.{Reset}

{Negrito}👥 Base Atual:{Reset}
{Verde}O total atualizado de clientes cadastrados é {Amarelo}{total_clientes}{Verde}, considerando todos os registros válidos disponíveis na base.{Reset}

{Negrito}Permanecemos à disposição para aprofundar análises adicionais, criar dashboards ou apoiar decisões estratégicas com base nesses dados.{Reset}

{Negrito}Atenciosamente,{Reset}
{Azul}Lucas Paguetti Pereira🇮🇹{Reset}
""")

print(mensagem_terminal)
